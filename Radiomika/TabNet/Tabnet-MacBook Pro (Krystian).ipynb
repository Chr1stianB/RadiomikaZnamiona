# %%
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler

from sklearn.preprocessing import MinMaxScaler    
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# %%
df = pd.read_csv("../Datasets/new_df_with_colors.csv")
df_val = pd.read_csv("../Datasets/new_df_with_colors_val.csv")
df.head()
# Out:
#    Unnamed: 0  original_firstorder_10Percentile  \
# 0           0                             143.0
# 1           1                             147.0
# 2           2                             166.0
# 3           3                             148.0
# 4           4                             131.0
#
#    original_firstorder_90Percentile  original_firstorder_Energy  \
# 0                             198.0                2.629872e+09
# 1                             207.0                1.078346e+09
# 2                             195.0                2.396981e+09
# 3                             193.0                6.335824e+08
# 4                             205.0                3.038574e+09
#
#    original_firstorder_Entropy  original_firstorder_InterquartileRange  \
# 0                     1.855826                                    28.0
# 1                     1.966402                                    31.0
# 2                     1.046078                                    14.0
# 3                     1.682122                                    24.0
# 4                     2.224188                                    40.0
#
#    original_firstorder_Kurtosis  original_firstorder_Maximum  \
# 0                      4.010590                        239.0
# 1                      3.860063                        245.0
# 2                      6.558719                        234.0
# 3                      4.467119                        235.0
# 4                      2.553326                        252.0
#
#    original_firstorder_Mean  original_firstorder_MeanAbsoluteDeviation  ...  \
# 0                174.128763                                  17.301452  ...
# 1                181.065912                                  18.659672  ...
# 2                181.899567                                   9.019767  ...
# 3                171.007333                                  14.422398  ...
# 4                169.531399                                  22.868935  ...
#
#    original_shape2D_PerimeterSurfaceRatio  original_shape2D_PixelSurface  \
# 0                                0.014951                        85335.0
# 1                                0.024128                        32331.0
# 2                                0.016030                        72118.0
# 3                                0.028375                        21411.0
# 4                                0.012622                       102932.0
#
#    original_shape2D_Sphericity     mean_b     mean_g     mean_r      std_b  \
# 0                     0.811662  14.717348  31.194178  27.761522  22.964014
# 1                     0.817094   4.828563  10.884811   9.997270  13.993032
# 2                     0.823484  10.972730  22.767644  27.615070  18.936728
# 3                     0.853791   3.088996   8.492770   7.289537  11.161337
# 4                     0.875376  20.113989  37.382422  43.925978  32.360352
#
#        std_g      std_r  category
# 0  47.941269  45.568054         2
# 1  30.921559  30.106340         2
# 2  38.366805  46.765206         2
# 3  29.530677  25.941221         2
# 4  50.460714  59.286744         2
#
# [5 rows x 110 columns]

# %%
df_val.head()
# Out:
#    Unnamed: 0  original_firstorder_10Percentile  \
# 0           0                              95.0
# 1           1                              81.0
# 2           2                             101.0
# 3           3                              91.0
# 4           4                              81.0
#
#    original_firstorder_90Percentile  original_firstorder_Energy  \
# 0                             152.0                1.732030e+09
# 1                             169.0                1.052841e+09
# 2                             153.0                5.715280e+08
# 3                             188.0                1.483424e+09
# 4                             167.0                1.597289e+09
#
#    original_firstorder_Entropy  original_firstorder_InterquartileRange  \
# 0                     1.890115                                    31.0
# 1                     2.324632                                    61.0
# 2                     1.773241                                    33.0
# 3                     2.515330                                    62.0
# 4                     2.395141                                    51.0
#
#    original_firstorder_Kurtosis  original_firstorder_Maximum  \
# 0                      2.585449                        192.0
# 1                      1.743730                        189.0
# 2                      2.048065                        186.0
# 3                      1.887613                        224.0
# 4                      2.125963                        194.0
#
#    original_firstorder_Mean  original_firstorder_MeanAbsoluteDeviation  ...  \
# 0                121.081493                                  17.878740  ...
# 1                128.086137                                  29.810952  ...
# 2                124.923260                                  17.135367  ...
# 3                137.420878                                  31.746040  ...
# 4                122.326723                                  27.065350  ...
#
#    original_shape2D_PerimeterSurfaceRatio  original_shape2D_PixelSurface  \
# 0                                0.011851                       114403.0
# 1                                0.018178                        60032.0
# 2                                0.021967                        35705.0
# 3                                0.015236                        73361.0
# 4                                0.013242                        99843.0
#
#    original_shape2D_Sphericity     mean_b     mean_g     mean_r      std_b  \
# 0                     0.884403  28.179111  68.628359  74.191019  35.172910
# 1                     0.795902  16.137630  33.865889  32.803652  33.940358
# 2                     0.854027  11.925352  20.037670  17.615578  30.788006
# 3                     0.859014  19.129211  37.627596  38.738448  34.353198
# 4                     0.847239  31.257804  56.723781  59.613115  42.819618
#
#        std_g      std_r  category
# 0  81.493415  87.942944         4
# 1  65.392555  63.362894         4
# 2  52.044319  46.357505         6
# 3  65.049195  67.615075         0
# 4  77.350374  81.317964         4
#
# [5 rows x 110 columns]

# %%
sns.countplot(x = 'category', data=df)
# Out:
# <Axes: xlabel='category', ylabel='count'>

# %%
sns.countplot(x = 'category', data=df_val)
# Out:
# <Axes: xlabel='category', ylabel='count'>

# %%
X = df.iloc[:, 0:-1]
y = df.iloc[:, -1]
X_train = df.iloc[:, 0:-1]
y_train = df.iloc[:, -1]
X_val = df_val.iloc[:, 0:-1]
y_val = df_val.iloc[:, -1]

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
#X_test = scaler.transform(X_test)
X_train, y_train = np.array(X_train), np.array(y_train)
X_val, y_val = np.array(X_val), np.array(y_val)
#X_test, y_test = np.array(X_test), np.array(y_test)

# %%
def get_class_distribution(obj):
    count_dict = {
        "akiec": 0,
        "bcc": 0,
        "bkl": 0,
        "df": 0,
        "nv": 0,
        "vasc": 0,
        "mel": 0
    }
    
    for i in obj:
        if i == 0: 
            count_dict['akiec'] += 1
        elif i == 1: 
            count_dict['bcc'] += 1
        elif i == 2: 
            count_dict['bkl'] += 1
        elif i == 3: 
            count_dict['df'] += 1
        elif i == 4: 
            count_dict['nv'] += 1  
        elif i == 5: 
            count_dict['vasc'] += 1 
        elif i == 6:
            count_dict['mel'] += 1           
        else:
            print("Check classes.")
            
    return count_dict

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(25,7))
# Train
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(y_train)]).melt(), x = "variable", y="value", hue="variable",  ax=axes[0]).set_title('Dystrybucja klas w zbiorze treningowym')
# Validation
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(y_val)]).melt(), x = "variable", y="value", hue="variable",  ax=axes[1]).set_title('Dystrybucja klas w zbiorze walidacyjnym')
# Out:
# Text(0.5, 1.0, 'Dystrybucja klas w zbiorze walidacyjnym')

# %%
class ClassifierDataset(Dataset):
    
    def __init__(self, X_data, y_data):
        self.X_data = X_data
        self.y_data = y_data
        
    def __getitem__(self, index):
        return self.X_data[index], self.y_data[index]
        
    def __len__ (self):
        return len(self.X_data)


train_dataset = ClassifierDataset(torch.from_numpy(X_train).float(), torch.from_numpy(y_train).long())
val_dataset = ClassifierDataset(torch.from_numpy(X_val).float(), torch.from_numpy(y_val).long())

# %%
target_list = []
for _, t in train_dataset:
    target_list.append(t)
    
target_list = torch.tensor(target_list)

# %%
class_count = [i for i in get_class_distribution(y_train).values()]
class_weights = 1./torch.tensor(class_count, dtype=torch.float)

# %%
print(class_weights)
# Out:
# tensor([0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002])

# %%
class_weights_all = class_weights[target_list]

# %%
weighted_sampler = WeightedRandomSampler(
    weights=class_weights_all,
    num_samples=len(class_weights_all),
    replacement=True
)

# %%
EPOCHS = 20
BATCH_SIZE = 32
LEARNING_RATE = 0.0007
NUM_FEATURES = len(X.columns)
NUM_CLASSES = 7

# %%
train_loader = DataLoader(dataset=train_dataset,
                          batch_size=BATCH_SIZE,
                          sampler=weighted_sampler
)
val_loader = DataLoader(dataset=val_dataset, batch_size=1)

# %%
class MulticlassClassification(nn.Module):
    def __init__(self, num_feature, num_class):
        super(MulticlassClassification, self).__init__()
        
        self.layer_1 = nn.Linear(num_feature, 512)
        self.layer_2 = nn.Linear(512, 128)
        self.layer_3 = nn.Linear(128, 64)
        self.layer_out = nn.Linear(64, num_class) 
        
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.2)
        self.batchnorm1 = nn.BatchNorm1d(512)
        self.batchnorm2 = nn.BatchNorm1d(128)
        self.batchnorm3 = nn.BatchNorm1d(64)
        
    def forward(self, x):
        x = self.layer_1(x)
        x = self.batchnorm1(x)
        x = self.relu(x)
        
        x = self.layer_2(x)
        x = self.batchnorm2(x)
        x = self.relu(x)
        x = self.dropout(x)
        
        x = self.layer_3(x)
        x = self.batchnorm3(x)
        x = self.relu(x)
        x = self.dropout(x)
        
        x = self.layer_out(x)
        
        return x

# %%
device = torch.device("mps:0" if torch.backends.mps.is_available() else "cpu")

# %%
model = MulticlassClassification(num_feature = NUM_FEATURES, num_class=NUM_CLASSES)
model.to(device)

criterion = nn.CrossEntropyLoss(weight=class_weights.to(device))
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
print(model)
# Out:
# MulticlassClassification(
#   (layer_1): Linear(in_features=109, out_features=512, bias=True)
#   (layer_2): Linear(in_features=512, out_features=128, bias=True)
#   (layer_3): Linear(in_features=128, out_features=64, bias=True)
#   (layer_out): Linear(in_features=64, out_features=7, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
#   (batchnorm1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
def multi_acc(y_pred, y_test):
    y_pred_softmax = torch.log_softmax(y_pred, dim = 1)
    _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)    
    
    correct_pred = (y_pred_tags == y_test).float()
    acc = correct_pred.sum() / len(correct_pred)
    
    acc = torch.round(acc * 100)
    
    return acc

# %%
accuracy_stats = {
    'train': [],
    "val": []
}
loss_stats = {
    'train': [],
    "val": []
}

# %%
print("Begin training.")
for e in tqdm(range(1, EPOCHS+1)):
    
    # TRAINING
    train_epoch_loss = 0
    train_epoch_acc = 0
    model.train()
    for X_train_batch, y_train_batch in train_loader:
        X_train_batch, y_train_batch = X_train_batch.to(device), y_train_batch.to(device)
        optimizer.zero_grad()
        
        y_train_pred = model(X_train_batch)
        
        train_loss = criterion(y_train_pred, y_train_batch)
        train_acc = multi_acc(y_train_pred, y_train_batch)
        
        train_loss.backward()
        optimizer.step()
        
        train_epoch_loss += train_loss.item()
        train_epoch_acc += train_acc.item()
    # VALIDATION    
    with torch.no_grad():
        
        val_epoch_loss = 0
        val_epoch_acc = 0
        
        model.eval()
        for X_val_batch, y_val_batch in val_loader:
            X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)
            
            y_val_pred = model(X_val_batch)
                        
            val_loss = criterion(y_val_pred, y_val_batch)
            val_acc = multi_acc(y_val_pred, y_val_batch)
            
            val_epoch_loss += val_loss.item()
            val_epoch_acc += val_acc.item()
        loss_stats['train'].append(train_epoch_loss/len(train_loader))
        loss_stats['val'].append(val_epoch_loss/len(val_loader))
        accuracy_stats['train'].append(train_epoch_acc/len(train_loader))
        accuracy_stats['val'].append(val_epoch_acc/len(val_loader))
                              
    
    print(f'Epoch {e+0:03}: | Train Loss:{train_epoch_loss/len(train_loader):.5f} | Val Loss:{val_epoch_loss/len(val_loader):.5f} | Train Acc:{train_epoch_acc/len(train_loader):.3f}| Val Acc: {val_epoch_acc/len(val_loader):.3f}')
# Out:
# Begin training.
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 001: | Train Loss:0.68978 | Val Loss:0.75845 | Train Acc:75.793| Val Acc: 76.156
# Epoch 002: | Train Loss:0.46451 | Val Loss:0.68434 | Train Acc:82.833| Val Acc: 76.519
# Epoch 003: | Train Loss:0.41982 | Val Loss:0.64967 | Train Acc:84.643| Val Acc: 78.332
# Epoch 004: | Train Loss:0.39147 | Val Loss:0.90392 | Train Acc:85.525| Val Acc: 73.708
# Epoch 005: | Train Loss:0.36194 | Val Loss:0.77706 | Train Acc:86.641| Val Acc: 75.249
# Epoch 006: | Train Loss:0.35304 | Val Loss:1.11428 | Train Acc:87.098| Val Acc: 68.903
# Epoch 007: | Train Loss:0.32990 | Val Loss:1.07490 | Train Acc:88.074| Val Acc: 65.186
# Epoch 008: | Train Loss:0.31416 | Val Loss:2.15805 | Train Acc:88.410| Val Acc: 31.460
# Epoch 009: | Train Loss:0.30115 | Val Loss:1.00632 | Train Acc:88.964| Val Acc: 70.716
# Epoch 010: | Train Loss:0.28615 | Val Loss:1.30224 | Train Acc:89.727| Val Acc: 63.282
# Epoch 011: | Train Loss:0.27568 | Val Loss:0.97692 | Train Acc:90.024| Val Acc: 71.714
# Epoch 012: | Train Loss:0.26489 | Val Loss:0.95843 | Train Acc:90.470| Val Acc: 71.985
# Epoch 013: | Train Loss:0.25465 | Val Loss:1.21321 | Train Acc:90.901| Val Acc: 66.274
# Epoch 014: | Train Loss:0.24337 | Val Loss:1.07909 | Train Acc:91.263| Val Acc: 70.354
# Epoch 015: | Train Loss:0.23748 | Val Loss:1.05100 | Train Acc:91.563| Val Acc: 71.895
# Epoch 016: | Train Loss:0.23242 | Val Loss:1.93586 | Train Acc:91.651| Val Acc: 40.435
# Epoch 017: | Train Loss:0.23348 | Val Loss:0.83731 | Train Acc:91.799| Val Acc: 76.791
# Epoch 018: | Train Loss:0.22379 | Val Loss:1.24783 | Train Acc:91.926| Val Acc: 62.013
# Epoch 019: | Train Loss:0.21350 | Val Loss:1.02560 | Train Acc:92.426| Val Acc: 70.263
# Epoch 020: | Train Loss:0.20940 | Val Loss:1.04310 | Train Acc:92.446| Val Acc: 73.073

# %%
# Create dataframes
train_val_acc_df = pd.DataFrame.from_dict(accuracy_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
train_val_loss_df = pd.DataFrame.from_dict(loss_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
# Plot the dataframes
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,7))
sns.lineplot(data=train_val_acc_df, x = "epochs", y="value", hue="variable",  ax=axes[0]).set_title('Train-Val Accuracy/Epoch')
sns.lineplot(data=train_val_loss_df, x = "epochs", y="value", hue="variable", ax=axes[1]).set_title('Train-Val Loss/Epoch')
# Out:
# Text(0.5, 1.0, 'Train-Val Loss/Epoch')

# %%
y_pred_list = []
with torch.no_grad():
    model.eval()
    for X_batch, _ in val_loader:
        X_batch = X_batch.to(device)
        y_test_pred = model(X_batch)
        _, y_pred_tags = torch.max(y_test_pred, dim = 1)
        y_pred_list.append(y_pred_tags.cpu().numpy())
y_pred_list = [a.squeeze().tolist() for a in y_pred_list]

# %%
column_class = ['akiec', 'bcc', 'bkl', 'df', 'nv', 'vasc', 'mel']
confusion_matrix_df = pd.DataFrame(confusion_matrix(y_val, y_pred_list)).rename(columns=column_class, index=column_class)

sns.heatmap(confusion_matrix_df, annot=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/krystian/Library/CloudStorage/OneDrive-Osobisty/JupyterNotebook/TabNet/Tabnet.ipynb Komórka 26 line 2
#       <a href='vscode-notebook-cell:/Users/krystian/Library/CloudStorage/OneDrive-Osobisty/JupyterNotebook/TabNet/Tabnet.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> column_class = ['akiec', 'bcc', 'bkl', 'df', 'nv', 'vasc', 'mel']
# ----> <a href='vscode-notebook-cell:/Users/krystian/Library/CloudStorage/OneDrive-Osobisty/JupyterNotebook/TabNet/Tabnet.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a> confusion_matrix_df = pd.DataFrame(confusion_matrix(y_val, y_pred_list)).rename(columns=column_class, index=column_class)
#       <a href='vscode-notebook-cell:/Users/krystian/Library/CloudStorage/OneDrive-Osobisty/JupyterNotebook/TabNet/Tabnet.ipynb#X34sZmlsZQ%3D%3D?line=3'>4</a> sns.heatmap(confusion_matrix_df, annot=True)
#
# File ~/anaconda3/envs/scikit/lib/python3.11/site-packages/pandas/core/frame.py:5432, in DataFrame.rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    5313 def rename(
#    5314     self,
#    5315     mapper: Renamer | None = None,
#    (...)
#    5323     errors: IgnoreRaise = "ignore",
#    5324 ) -> DataFrame | None:
#    5325     """
#    5326     Rename columns or index labels.
#    5327
#    (...)
#    5430     4  3  6
#    5431     """
# -> 5432     return super()._rename(
#    5433         mapper=mapper,
#    5434         index=index,
#    5435         columns=columns,
#    5436         axis=axis,
#    5437         copy=copy,
#    5438         inplace=inplace,
#    5439         level=level,
#    5440         errors=errors,
#    5441     )
#
# File ~/anaconda3/envs/scikit/lib/python3.11/site-packages/pandas/core/generic.py:1034, in NDFrame._rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    1027         missing_labels = [
#    1028             label
#    1029             for index, label in enumerate(replacements)
#    1030             if indexer[index] == -1
#    1031         ]
#    1032         raise KeyError(f"{missing_labels} not found in axis")
# -> 1034 new_index = ax._transform_index(f, level=level)
#    1035 result._set_axis_nocheck(new_index, axis=axis_no, inplace=True, copy=False)
#    1036 result._clear_item_cache()
#
# File ~/anaconda3/envs/scikit/lib/python3.11/site-packages/pandas/core/indexes/base.py:6207, in Index._transform_index(self, func, level)
#    6205     return type(self).from_arrays(values)
#    6206 else:
# -> 6207     items = [func(x) for x in self]
#    6208     return Index(items, name=self.name, tupleize_cols=False)
#
# File ~/anaconda3/envs/scikit/lib/python3.11/site-packages/pandas/core/indexes/base.py:6207, in <listcomp>(.0)
#    6205     return type(self).from_arrays(values)
#    6206 else:
# -> 6207     items = [func(x) for x in self]
#    6208     return Index(items, name=self.name, tupleize_cols=False)
#
# TypeError: 'list' object is not callable
